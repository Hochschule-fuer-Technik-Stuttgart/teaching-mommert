# %% [markdown]
# # Supervised Classification with Machine Learning Methods for Sentinel-2 Satellite Imagery
#
# Michael Mommert, Stuttgart University of Applied Sciences, 2024
#
# This Notebook introduces different supervised machine learning methods for pixel-wise classification. We will apply these methods to Sentinel-2 satellite images from the [*ben-ge-800* dataset](https://zenodo.org/records/12941231) to perform pixel-wise classification based on land-use/land-cover information.

# %%
! pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: matplotlib in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (3.7.2)
# Requirement already satisfied: rasterio in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (1.3.9)
# Requirement already satisfied: scikit-learn in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (1.3.0)
# Collecting ipympl (from -r requirements.txt (line 5))
#   Obtaining dependency information for ipympl from https://files.pythonhosted.org/packages/d8/50/d6f4e7eb0e7d198b431d8259bc9a6035f879d4df487448b196cdf1e84155/ipympl-0.9.4-py3-none-any.whl.metadata
#   Downloading ipympl-0.9.4-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 2)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 2)) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 2)) (10.2.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from matplotlib->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: affine in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from rasterio->-r requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: attrs in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from rasterio->-r requirements.txt (line 3)) (23.2.0)
# Requirement already satisfied: certifi in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from rasterio->-r requirements.txt (line 3)) (2023.7.22)
# Requirement already satisfied: click>=4.0 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from rasterio->-r requirements.txt (line 3)) (8.0.4)
# Requirement already satisfied: cligj>=0.5 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from rasterio->-r requirements.txt (line 3)) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from rasterio->-r requirements.txt (line 3)) (1.4.7)
# Requirement already satisfied: click-plugins in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from rasterio->-r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: setuptools in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from rasterio->-r requirements.txt (line 3)) (68.0.0)
# Requirement already satisfied: scipy>=1.5.0 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 4)) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from scikit-learn->-r requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: ipython-genutils in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipympl->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: ipython<9 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipympl->-r requirements.txt (line 5)) (8.15.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipympl->-r requirements.txt (line 5)) (8.0.4)
# Requirement already satisfied: traitlets<6 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipympl->-r requirements.txt (line 5)) (5.7.1)
# Requirement already satisfied: backcall in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipython<9->ipympl->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: decorator in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipython<9->ipympl->-r requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipython<9->ipympl->-r requirements.txt (line 5)) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipython<9->ipympl->-r requirements.txt (line 5)) (0.1.6)
# Requirement already satisfied: pickleshare in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipython<9->ipympl->-r requirements.txt (line 5)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipython<9->ipympl->-r requirements.txt (line 5)) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipython<9->ipympl->-r requirements.txt (line 5)) (2.15.1)
# Requirement already satisfied: stack-data in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipython<9->ipympl->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipython<9->ipympl->-r requirements.txt (line 5)) (4.8.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 5)) (6.25.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 5)) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 5)) (3.0.5)
# Requirement already satisfied: six>=1.5 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 5)) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 5)) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 5)) (5.3.0)
# Requirement already satisfied: nest-asyncio in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 5)) (1.5.6)
# Requirement already satisfied: psutil in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 5)) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 5)) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 5)) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from jedi>=0.16->ipython<9->ipympl->-r requirements.txt (line 5)) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from pexpect>4.3->ipython<9->ipympl->-r requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9->ipympl->-r requirements.txt (line 5)) (0.2.5)
# Requirement already satisfied: executing in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl->-r requirements.txt (line 5)) (0.8.3)
# Requirement already satisfied: asttokens in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl->-r requirements.txt (line 5)) (2.0.5)
# Requirement already satisfied: pure-eval in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from stack-data->ipython<9->ipympl->-r requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: entrypoints in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 5)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /home/mommermi/software/anaconda/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl->-r requirements.txt (line 5)) (3.10.0)
# Downloading ipympl-0.9.4-py3-none-any.whl (516 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 516.3/516.3 kB 710.2 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Installing collected packages: ipympl
# Successfully installed ipympl-0.9.4

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import rasterio

# %% [markdown]
# ## Data Download
#
# We download the *ben-ge-800* dataset and unpack it:

# %%
# !wget https://zenodo.org/records/12941231/files/ben-ge-800.tar.gz?download=1 -O ben-ge-800.tar.gz

import tarfile 
  
tarfile = tarfile.open('ben-ge-800.tar.gz')  # open ben-ge-800 tarball 
tarfile.extractall('./')  # extract tarball
# Out:
# --2024-08-22 10:40:25--  https://zenodo.org/records/12941231/files/ben-ge-800.tar.gz?download=1
# Resolving zenodo.org (zenodo.org)... 188.184.98.238, 188.184.103.159, 188.185.79.172, ...
# Connecting to zenodo.org (zenodo.org)|188.184.98.238|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 183201083 (175M) [application/octet-stream]
# Saving to: ‘ben-ge-800.tar.gz’
#
# ben-ge-800.tar.gz     2%[                    ]   4,63M   651KB/s    eta 3m 47s ^C
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[2], line 6
#       3 import tarfile
#       5 tarfile = tarfile.open('ben-ge-800.tar.gz')  # open ben-ge-800 tarball
# ----> 6 tarfile.extractall('./')
#
# File ~/software/anaconda/lib/python3.11/tarfile.py:2264, in TarFile.extractall(self, path, members, numeric_owner, filter)
#    2259     if tarinfo.isdir():
#    2260         # For directories, delay setting attributes until later,
#    2261         # since permissions can interfere with extraction and
#    2262         # extracting contents can reset mtime.
#    2263         directories.append(tarinfo)
# -> 2264     self._extract_one(tarinfo, path, set_attrs=not tarinfo.isdir(),
#    2265                       numeric_owner=numeric_owner)
#    2267 # Reverse sort directories.
#    2268 directories.sort(key=lambda a: a.name, reverse=True)
#
# File ~/software/anaconda/lib/python3.11/tarfile.py:2327, in TarFile._extract_one(self, tarinfo, path, set_attrs, numeric_owner)
#    2324 self._check("r")
#    2326 try:
# -> 2327     self._extract_member(tarinfo, os.path.join(path, tarinfo.name),
#    2328                          set_attrs=set_attrs,
#    2329                          numeric_owner=numeric_owner)
#    2330 except OSError as e:
#    2331     self._handle_fatal_error(e)
#
# File ~/software/anaconda/lib/python3.11/tarfile.py:2410, in TarFile._extract_member(self, tarinfo, targetpath, set_attrs, numeric_owner)
#    2407     self._dbg(1, tarinfo.name)
#    2409 if tarinfo.isreg():
# -> 2410     self.makefile(tarinfo, targetpath)
#    2411 elif tarinfo.isdir():
#    2412     self.makedir(tarinfo, targetpath)
#
# File ~/software/anaconda/lib/python3.11/tarfile.py:2463, in TarFile.makefile(self, tarinfo, targetpath)
#    2461     target.truncate()
#    2462 else:
# -> 2463     copyfileobj(source, target, tarinfo.size, ReadError, bufsize)
#
# File ~/software/anaconda/lib/python3.11/tarfile.py:258, in copyfileobj(src, dst, length, exception, bufsize)
#     255     dst.write(buf)
#     257 if remainder != 0:
# --> 258     buf = src.read(remainder)
#     259     if len(buf) < remainder:
#     260         raise exception("unexpected end of data")
#
# File ~/software/anaconda/lib/python3.11/gzip.py:301, in GzipFile.read(self, size)
#     299     import errno
#     300     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 301 return self._buffer.read(size)
#
# File ~/software/anaconda/lib/python3.11/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
#      69         byte_view[:len(data)] = data
#      70     return len(data)
#
# File ~/software/anaconda/lib/python3.11/gzip.py:518, in _GzipReader.read(self, size)
#     516         break
#     517     if buf == b"":
# --> 518         raise EOFError("Compressed file ended before the "
#     519                        "end-of-stream marker was reached")
#     521 self._add_read_data( uncompress )
#     522 self._pos += len(uncompress)
#
# EOFError: Compressed file ended before the end-of-stream marker was reached

# %% [markdown]
# Ben-ge-800 contains 800 samples ...
#
# Each image is represented by 12 TIF files, each containing a separate band. Note that some of these bands have different GSDs.
#
# We read in the R, G and B band for a single scene:

# %%
sen2_path = 'ben-ge-800/sentinel-2/'
filename = 'S2B_MSIL2A_20180525T94030_7_51'
bands = ['B04', 'B03', 'B02']  # R, G, B

data = []
for band in bands:
    dataset = rasterio.open(os.path.join(sen2_path, filename, filename+'_'+band+'.tif'))
    data.append(dataset.read(1))
data = np.array(data)
data.shape
# Out:
# (3, 120, 120)

# %% [markdown]
# The data is now stored as a Numpy array, following the shape convention `[bands, height, width]`.
#
# Let's display this image. In order to do so, we have to do two things:
#
# 1. we have to change the shape to `[height, width, bands]` (this particular shape is expected by matplotlib)
# 2. we have to normalize the pixel values (which vary on a large range) to a range from 0 to 1.

# %%
img = np.dstack(data)

# then we normalize the pixel values in such a way that they range from 0 (min) to 1 (max)
img = (img-np.min(img, axis=(0,1)))/(np.max(img, axis=(0,1)) - np.min(img, axis=(0,1)))

# now we can plot the image
plt.imshow(img)

# %% [markdown]
# This looks good.
#
# Now, let's read in all scenes from the dataset. In this tutorial, we will not only use the RGB data, but also band 8, which contains NIR data. We will ignore the other bands, which saves us the effort of having to rescale those other bands (although this could be easily done with image interpolation techniques). Reading in all images takes a few seconds:

# %%
filelist = os.listdir(sen2_path)
bands = ['B04', 'B03', 'B02', 'B08']  # R, G, B, NIR

data = []
for filename in filelist:
    scene = []
    for band in bands:
        dataset = rasterio.open(os.path.join(sen2_path, filename, filename+'_'+band+'.tif'))
        scene.append(dataset.read(1))
    data.append(np.stack(scene, axis=0))
data = np.stack(data, axis=0)

# %% [markdown]
# Before we move on, we scale the data appropriately. For this purpose, we simply scale each band by the mean value in each band:

# %%
data = data/data.mean(axis=(0, 2, 3)).reshape(1, 4, 1, 1)

# %% [markdown]
# Now we can easily access any scene from our dataset:

# %%
i = 33 # image index

img = np.dstack([data[i][0], data[i][1], data[i][2]])  # we extract the R, G, B bands for this scene

# then we normalize the pixel values in such a way that they range from 0 (min) to 1 (max)
img = (img-np.min(img, axis=(0,1)))/(np.max(img, axis=(0,1)) - np.min(img, axis=(0,1)))

# now we can plot the image
plt.imshow(img)

# %% [markdown]
# In order to provide ground-truth data for our supervised learning methods, we have to define specific image areas through their coordinates. The easiest way would be to select two opposing corners of a rectangle. To find the coordinates of these corners, we can use the interactive mode provided by Matplolib. This mode allows you to modify your images in very simple ways.
#
# Most importantly for us, we can extract image coordinates by moving our mouse over the region of interest:

# %%
# %matplotlib

plt.imshow(img)
plt.show()
# Out:
# Using matplotlib backend: <object object at 0x7e716d407310>
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""
# libGL error: MESA-LOADER: failed to open iris: /usr/lib/dri/iris_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
# libGL error: failed to load driver: iris
# libGL error: MESA-LOADER: failed to open swrast: /usr/lib/dri/swrast_dri.so: cannot open shared object file: No such file or directory (search paths /usr/lib/x86_64-linux-gnu/dri:\$${ORIGIN}/dri:/usr/lib/dri, suffix _dri)
# libGL error: failed to load driver: swrast

# %% [markdown]
# For instance, a rectabgular region containing grassland can be defined through the corner coordinates (45, 100) and (65, 75). Note that these coordinates are provided as (x, y).
#
# To validate our selection, we can crop this image region. Keep in mind that when slicing arrays, the coordinates are juxtaposed: pixel coordinates should be provided as (row, column), which is equivalent to (y, x). So, in order to define a rectangular area, we have to provide pixel coordinates as $$[y_{min}:y_{max}, x_{min}:x_{max}]$$

# %%
# %matplotlib inline
plt.imshow(img[75:100, 45:65])
plt.show()

# %% [markdown]
# Nice. We now have the capability to select image regions and build a catalog of ground-truth data for training our models.

# %% [markdown]
# ## Data Annotations
#
# The availability of labeled examples forms the core of the supervised learning process, in which a model is trained based on these examples.
#
# In the following, we will use the scene from above and label three regions from this image into separate classes. These classes will be `grassland`, `forest` and `water`.
#
# We use the same method as above to extract pixel coordinates of rectangular regions containing either of these classes:

# %%
# %matplotlib

plt.imshow(img)
plt.show()
# Out:
# Using matplotlib backend: QtAgg

# %% [markdown]
# We find a rectangular area covering forest in the area enclosed by the point (0, 40) and (40, 0). Let's verify:

# %%
# %matplotlib inline
plt.imshow(img[0:40, 0:40])
plt.show()

# %% [markdown]
# And we find surface water enclosed by the points (110, 60) and (120, 0). Let's verify:

# %%
# %matplotlib inline
plt.imshow(img[0:60, 110:120])
plt.show()

# %% [markdown]
# Including the grassland area from above, we now defined three areas - on for each class. These areas will serve as training input data for our supervised learning approach.
#
# We extract the pixel values from each area into separate arrays for further processing:

# %%
X_grassland = np.dstack(data[i, :, 75:100, 45:65]).reshape(-1, 4)
X_forest = np.dstack(data[i, :, 0:40, 0:40]).reshape(-1, 4)
X_water = np.dstack(data[i, :, 0:60, 110:120]).reshape(-1, 4)

X_grassland.shape, X_forest.shape, X_water.shape
# Out:
# ((500, 4), (1600, 4), (600, 4))

# %% [markdown]
# Before we move on, we will have a look at the spectral distribution of pixels. Since it is impossible to plot a 4-dimensional dataset, we will only plot the

# %%
f, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.scatter(data[i, 1].flatten(), data[i, 3].flatten(), c='grey', edgecolor='none', alpha=0.2)
ax.set_xlabel('G (scaled)')
ax.set_ylabel('NIR (scaled)')

ax.scatter(X_grassland[:, 1], X_grassland[:, 3], c='limegreen', edgecolor='none', alpha=0.5, label='grassland')
ax.scatter(X_forest[:, 1], X_forest[:, 3], c='darkgreen', edgecolor='none', alpha=0.5, label='forest')
ax.scatter(X_water[:, 1], X_water[:, 3], c='blue', edgecolor='none', alpha=0.5, label='water')

ax.legend()

# %% [markdown]
# It becomes obvious that all three class occupy different spaces in their Green-Nearinfrared space. We will leverage this observation in the following.
#
# But before we do so, we will compile a training dataset in which we combine the pixels with their corresponding class labels. The result of this will be one array, `X_data`, which we will use as input to our model and `y_data`, which will will contain the corresponding labels. Finally, we will split these arrays into our training, validation and test data split (70%/15%/15%) in a stratified fashion.

# %%
from sklearn.model_selection import train_test_split

# compile input and labels for previously annotated data
X_data = np.concatenate([X_grassland, X_forest, X_water], axis=0)
y_data = np.hstack([np.zeros(len(X_grassland)), np.ones(len(X_forest)), np.ones(len(X_water))*2])

# we split the entire dataset into a training (70%) and remain (30%) split; the remain fraction will be split into validation (50%) and test (50%) 
X_train, X_remain, y_train, y_remain = train_test_split(X_data, y_data, train_size=0.7, shuffle=True, random_state=42, stratify=y_data)
X_val, X_test, y_val, y_test = train_test_split(X_remain, y_remain, train_size=0.5, shuffle=True, random_state=42, stratify=y_remain)

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape
# Out:
# ((1889, 4), (1889,), (405, 4), (405,), (406, 4), (406,))

# %% [markdown]
# ## Maximum Likelihood Classification
#
# We start with a simple Maximum Likelihood Classification method to classify all pixels in our scene. The idea behind the method is simple. We assign each pixel, $x_i$, to that class $C_j \in (grassland, forest, water)$ that has the highest probability $P(C_J | x_i)$ of having the individual spectral characteristics of this pixel. We approximate this probability of belonging to a class $j$ through a multinormal distribution: $$P(C_j | x_i) = N(x_i | \mu_j, \Sigma_j)$$
#
# In doing so, the multinormal distribution approximates the spectral characteristics of each class through mean colors ($\mu_j$) and corresponding covariances ($\Sigma_j$). Our first step is to compute these mean values and covariances for each class.

# %%
# compute mean pixel values for each band and class ([grassland, forest, water])
means = np.stack([np.nanmean(X_train[y_train==0], axis=0),
                  np.nanmean(X_train[y_train==1], axis=0),
                  np.nanmean(X_train[y_train==2], axis=0)], axis=0)


# compute covariance matrices for each class ([grassland, forest, water])
covs = np.stack([np.cov(X_train[y_train==0].transpose()),
                 np.cov(X_train[y_train==1].transpose()),
                 np.cov(X_train[y_train==2].transpose())], axis=0)

# %% [markdown]
# Let's see whether the mean values agree with the spectral areas of our three classes:

# %%
f, ax = plt.subplots(1, 1, figsize=(5, 5))
ax.scatter(data[i, 1].flatten(), data[i, 3].flatten(), c='grey', edgecolor='none', alpha=0.2)
ax.set_xlabel('R (scaled)')
ax.set_ylabel('G (scaled)')

ax.scatter(X_grassland[:, 1], X_grassland[:, 3], c='limegreen', edgecolor='none', alpha=0.5, label='grassland')
ax.scatter(X_forest[:, 1], X_forest[:, 3], c='darkgreen', edgecolor='none', alpha=0.5, label='forest')
ax.scatter(X_water[:, 1], X_water[:, 3], c='blue', edgecolor='none', alpha=0.5, label='water')

ax.scatter(means[0][1], means[0][3], c='limegreen', s=200, edgecolor='black', label='mean grassland')
ax.scatter(means[1][1], means[1][3], c='darkgreen', s=200, edgecolor='black', label='mean forest')
ax.scatter(means[2][1], means[2][3], c='blue', s=200, edgecolor='black', label='mean water')

ax.legend()

# %% [markdown]
# Yes, the means are representative for the different classes.
#
# Now, we can employs these means and covariances to find the most likely class of each pixel:

# %%
from scipy.stats import multivariate_normal

def maximum_likelihood_classifier(data, means, covs):
    """This function takes as input an array-like dataset (pixelwise band values), band mean values and corresponding covariances.
    The output consists of the most likely class for each pixel, as well as the probabilities for all classes"""
    p = []
    for j in range(3):
        p.append(multivariate_normal.pdf(data, mean=means[j], cov=covs[j]))
    return np.argmax(p, axis=0), np.array(p)

pred, prob = maximum_likelihood_classifier(np.dstack(data[i]).reshape(-1, 4), means, covs)

# %% [markdown]
# We can plot the result:

# %%
from matplotlib.colors import LinearSegmentedColormap, ListedColormap

# create a colormap
colors = ['limegreen',  # grassland 
          'darkgreen',  # forest
          'blue']  # water
cmap = LinearSegmentedColormap.from_list("cmap", colors)

# create a plot
f, ax = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(12, 6))

img = np.dstack([data[i][0], data[i][1], data[i][2]])  # we extract the R, G, B bands for this scene
img = (img-np.min(img, axis=(0,1)))/(np.max(img, axis=(0,1)) - np.min(img, axis=(0,1)))
ax[0].imshow(img)

ax[1].imshow(pred.reshape(120, 120), cmap=cmap)

# %% [markdown]
# This looks already pretty good!
#
# **Exercise**: Apply the model to different image from our dataset. Does it work as well? If not, why?

# %% [markdown]
# # use this cell for the exercise

# %% [markdown]
# ## Model Evaluation
#
# Qualitatively, the results look promising. Does the same apply to the quantitative results?
#
# We can evaluate our model performance on our test dataset, which is independent from our training dataset. As our performance metric, we choose the accuracy metric.

# %%
from sklearn.metrics import accuracy_score

# compute predictions for our test dataset
pred, prob = maximum_likelihood_classifier(X_test, means, covs)

# compute accuracy score
print("accuracy:", accuracy_score(pred, y_test))
# Out:
# accuracy: 0.9729064039408867

# %% [markdown]
# This is a very good result! Let's see, whether we can improve on this result...

# %% [markdown]
# ## k-Nearest Neighbor Classification
#
# Maximum Likelihood is a rather simple classification model. We will now employ a nearest neighbor ($k=1$) model.

# %%
from sklearn.neighbors import KNeighborsClassifier

# instantiate the model
model = KNeighborsClassifier(1)

# "train" the model on the training dataset
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# As we did before, we plot the prediction for the entire scene:

# %%
# predict classes for each pixel
pred = model.predict(np.dstack(data[i]).reshape(-1, 4))

f, ax = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(12, 6))

img = np.dstack([data[i][0], data[i][1], data[i][2]])  # we extract the R, G, B bands for this scene
img = (img-np.min(img, axis=(0,1)))/(np.max(img, axis=(0,1)) - np.min(img, axis=(0,1)))
ax[0].imshow(img)

ax[1].imshow(pred.reshape(120, 120), cmap=cmap)

# %% [markdown]
# The qualitative result also looks very good! What about the accuracy metric?

# %%
from sklearn.metrics import accuracy_score

pred = model.predict(X_test)
accuracy_score(pred, y_test)
# Out:
# 0.9901477832512315

# %% [markdown]
# Well, the nearest neighbor classifier does indeed outperform the Maximum Likelihood model.
#
# We can look at the mistakes the model makes using a confusion matrix:

# %%
from sklearn.metrics import confusion_matrix
# todo: add seaborn confusion matrix

confusion_matrix(pred, y_test)
# Out:
# array([[ 72,   1,   0],
#        [  3, 240,   0],
#        [  0,   0,  90]])

# %% [markdown]
# **Exercise**: We did not tune the hyperparameter ($k$) of our model. Train and evaluate the model for $k=5$, $k=10$ and $k=50$. What is the accuracy on the validation dataset for each of those parameters?

# %%
# use this cell for the exercise
# Out:
# (2700, 4)

# %% [markdown]
# **Exercise**: Our training dataset is rather small. Add more data to our training dataset by extending the arrays `X_grassland`, `X_forest` and `X_water` with additional pixel areas (also from other images!).

# %%
# use this cell for the exercise
